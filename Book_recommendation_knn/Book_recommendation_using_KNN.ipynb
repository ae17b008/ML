# %%
import numpy as np
import pandas as pd
import math
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import matplotlib as mpl
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import magma
import pandas as pd

# %%
books_filename = 'Books.csv'
ratings_filename = 'Ratings.csv'

# %%
books = pd.read_csv(
    books_filename,
    encoding = "ISO-8859-1",
    sep=";",
    header=0,
    names=['isbn', 'title', 'author'],
    usecols=['isbn', 'title', 'author'],
    dtype={'isbn': 'str', 'title': 'str', 'author': 'str'})

ratings = pd.read_csv(
    ratings_filename,
    encoding = "ISO-8859-1",
    sep=";",
    header=0,
    names=['user', 'isbn', 'rating'],
    usecols=['user', 'isbn', 'rating'],
    dtype={'user': 'int32', 'isbn': 'str', 'rating': 'float32'})


counts1 = ratings['user'].value_counts()
counts2 = ratings['isbn'].value_counts()
# Removing users with less than 200 rating and books with less than 100 ratings
ratings = ratings[~ratings['user'].isin(counts1[counts1 < 200].index)]
ratings = ratings[~ratings['isbn'].isin(counts2[counts2 < 100].index)]


final_df = pd.merge(right=ratings, left = books, on="isbn")
# drop duplicates
final_df = final_df.drop_duplicates(subset=["title", "user"])

final_df_pivot = final_df.pivot(
  index='title',
  columns='user',
  values='rating'
).fillna(0)

# %%
final_df.title.unique()
# Out:
# array(['The Testament', 'Beloved (Plume Contemporary Fiction)',
#        'Wild Animus', 'Airframe', 'Timeline', 'To Kill a Mockingbird',
#        'Seabiscuit: An American Legend', "I'll Be Seeing You",
#        'From the Corner of His Eye', 'Isle of Dogs', 'Purity in Death',
#        "Left Behind: A Novel of the Earth's Last Days (Left Behind #1)",
#        'The Street Lawyer', 'Breathing Lessons', 'The Joy Luck Club',
#        'The Tao of Pooh', 'Seabiscuit', 'The Catcher in the Rye',
#        'Midnight in the Garden of Good and Evil: A Savannah Story',
#        "Pretend You Don't See Her", 'The Pillars of the Earth',
#        "Corelli's Mandolin : A Novel",
#        'The Five People You Meet in Heaven', 'The Beach House',
#        'Angels &amp; Demons', 'The Girl Who Loved Tom Gordon',
#        'The Sum of All Fears', 'Little Altars Everywhere: A Novel',
#        'Before I Say Good-Bye', 'Atonement : A Novel',
#        "Bridget Jones's Diary", 'The God of Small Things',
#        'The Big Bad Wolf: A Novel', 'Four Blind Mice', 'Congo',
#        'Plainsong (Vintage Contemporaries)',
#        'Body of Evidence (Kay Scarpetta Mysteries (Paperback))',
#        'All That Remains (Kay Scarpetta Mysteries (Paperback))',
#        'The Brethren', 'The King of Torts', 'Bleachers',
#        'Sisterhood of the Traveling Pants',
#        'Roses Are Red (Alex Cross Novels)', 'The Rescue',
#        'Manhattan Hunt Club', 'Girl with a Pearl Earring',
#        'Deception Point', 'Tis : A Memoir',
#        'Chicken Soup for the Soul (Chicken Soup for the Soul)',
#        'Wicked: The Life and Times of the Wicked Witch of the West',
#        'Life of Pi',
#        'Lies and the Lying Liars Who Tell Them: A Fair and Balanced Look at the Right',
#        'Secret History',
#        "Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))",
#        'The Weight of Water', 'Animal Farm', 'Catch 22',
#        'A Painted House', "Vinegar Hill (Oprah's Book Club (Paperback))",
#        'The Secret Life of Bees', 'Digital Fortress : A Thriller',
#        'The Client', 'Heart of the Sea (Irish Trilogy)',
#        'Jonathan Livingston Seagull', 'Moonlight Becomes You',
#        'Divine Secrets of the Ya-Ya Sisterhood : A Novel',
#        'The Perfect Storm : A True Story of Men Against the Sea',
#        'The Lovely Bones: A Novel', 'Hannibal',
#        'The Four Agreements: A Practical Guide to Personal Freedom',
#        'The Firm', 'A Widow for One Year', 'Empire Falls',
#        'Black and Blue', "She's Come Undone (Oprah's Book Club)",
#        'Nickel and Dimed: On (Not) Getting By in America',
#        "Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)",
#        'The Bean Trees', 'Daughter of Fortune',
#        'The Red Tent (Bestselling Backlist)',
#        'The Nanny Diaries: A Novel', 'Postmortem',
#        'While My Pretty One Sleeps', 'Three Junes', 'Back Roads',
#        "A Thousand Acres (Ballantine Reader's Circle)", 'Four Blondes',
#        "River's End", 'The Chamber', 'The Partner', 'Chosen Prey',
#        'Guilty as Sin', 'Night Sins',
#        'The Vampire Lestat (Vampire Chronicles, Book II)',
#        'The Mummy or Ramses the Damned', 'Daisy Fay and the Miracle Man',
#        "Angela's Ashes: A Memoir", 'The Next Accident',
#        'Fast Food Nation: The Dark Side of the All-American Meal',
#        'Echoes', 'One for the Money (Stephanie Plum Novels (Paperback))',
#        'Along Came a Spider (Alex Cross Novels)',
#        'Simple Abundance:  A Daybook of Comfort and Joy',
#        'Who Moved My Cheese? An Amazing Way to Deal with Change in Your Work and in Your Life',
#        "Where the Heart Is (Oprah's Book Club (Paperback))",
#        "The Girls' Guide to Hunting and Fishing", 'Icy Sparks',
#        'The Da Vinci Code', 'Bridget Jones : The Edge of Reason',
#        "The Pilot's Wife : A Novel Tag: Author of the Weight of Water (Oprah's Book Club (Hardcover))",
#        'Skipping Christmas', "Daddy's Little Girl", 'Nights in Rodanthe',
#        'Like Water for Chocolate: A Novel in Monthly Installments, With Recipes, Romances, and Home Remedies',
#        'The Two Towers (The Lord of the Rings, Part 2)',
#        "Suzanne's Diary for Nicholas", '2nd Chance',
#        'The Bad Beginning (A Series of Unfortunate Events, Book 1)',
#        'Me Talk Pretty One Day', 'The Door to December',
#        'About a Boy (Movie Tie-In)', 'Dreamcatcher',
#        "Smilla's Sense of Snow", "The Hitchhiker's Guide to the Galaxy",
#        'The Giver (21st Century Reference)', 'A Time to Kill',
#        'Charming Billy', 'Dark Paradise', 'Middlesex: A Novel',
#        'The Rainmaker', 'The Bad Place',
#        'The Amazing Adventures of Kavalier &amp; Clay',
#        'The Phantom Tollbooth', 'Dances With Wolves',
#        "The Princess Bride: S Morgenstern's Classic Tale of True Love and High Adventure",
#        'Degree of Guilt', 'SHIPPING NEWS',
#        'Anne of Green Gables (Anne of Green Gables Novels (Paperback))',
#        'Fall On Your Knees (Oprah #45)', 'While I Was Gone',
#        'The House of the Spirits', 'Interpreter of Maladies',
#        'Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#        "She's Come Undone (Oprah's Book Club (Paperback))",
#        'Dragonfly in Amber', 'Naked', 'Kiss the Girls',
#        'The Witching Hour (Lives of the Mayfair Witches)',
#        'Jack &amp; Jill (Alex Cross Novels)',
#        'The House on Mango Street (Vintage Contemporaries)',
#        'The Perks of Being a Wallflower',
#        "Daughter of Fortune : A Novel (Oprah's Book Club (Hardcover))",
#        'American Gods', 'Red Dragon', 'Jurassic Park', 'Neverwhere',
#        'The Thorn Birds',
#        'Forever... : A Novel of Good and Evil, Love and Hope',
#        'Memoirs of a Geisha Uk',
#        "Lamb : The Gospel According to Biff, Christ's Childhood Pal",
#        "The Color of Water: A Black Man's Tribute to His White Mother",
#        'Anne Frank: The Diary of a Young Girl',
#        'The Stand: Complete and Uncut',
#        'Shopaholic Takes Manhattan (Summer Display Opportunity)',
#        'Confessions of a Shopaholic (Summer Display Opportunity)',
#        'Table For Two', 'Good Omens', 'Message in a Bottle',
#        'Fatal Voyage', 'The Poisonwood Bible: A Novel',
#        'A Lesson Before Dying (Vintage Contemporaries (Paperback))',
#        'Jewel', 'Their Eyes Were Watching God: A Novel',
#        'A Prayer for Owen Meany', 'The Shipping News : A Novel',
#        "The No. 1 Ladies' Detective Agency (Today Show Book Club #8)",
#        'Shopgirl', 'Breath, Eyes, Memory',
#        'A Walk in the Woods: Rediscovering America on the Appalachian Trail (Official Guides to the Appalachian Trail)',
#        "The Kitchen God's Wife",
#        "Songs in Ordinary Time (Oprah's Book Club (Paperback))",
#        'The Last Juror',
#        'Valhalla Rising (Dirk Pitt Adventures (Paperback))',
#        'At Home in Mitford (The Mitford Years)', 'Bel Canto: A Novel',
#        'All Around the Town', 'A Civil Action', 'Faking It', 'The Loop',
#        'Good in Bed', "We'll Meet Again", 'How to Make an American Quilt',
#        'Ellen Foster', 'The Hours : A Novel', 'Cold Mountain : A Novel',
#        'Fried Green Tomatoes at the Whistle Stop Cafe',
#        'The Last Time They Met : A Novel', 'The Princess Diaries',
#        'A Heartbreaking Work of Staggering Genius',
#        "The Dress Lodger (Ballantine Reader's Circle)",
#        'The Fellowship of the Ring (The Lord of the Rings, Part 1)',
#        'The Blue Nowhere : A Novel', 'A Year in Provence', 'The Sparrow',
#        'Summer Sisters',
#        "What to Expect When You're Expecting (Revised Edition)",
#        'Miss Julia Speaks Her Mind : A Novel',
#        "Big Stone Gap: A Novel (Ballantine Reader's Circle)",
#        'The Reader',
#        "Back When We Were Grownups : A Novel (Ballantine Reader's Circle)",
#        'Black Notice', 'One for the Money (A Stephanie Plum Novel)',
#        'Lord of the Flies', 'Atlantis Found', 'The Alienist',
#        'Notes from a Small Island', 'Engaging The Enemy', 'Into the Wild',
#        'The Curious Incident of the Dog in the Night-Time (Today Show Book Club #13)',
#        'The Smoke Jumper', 'Cause of Death',
#        'The Alchemist: A Fable About Following Your Dream',
#        'The Poisonwood Bible', 'Point of Origin', 'Rising Sun',
#        'Black Friday', '1st to Die: A Novel',
#        'Into Thin Air : A Personal Account of the Mt. Everest Disaster',
#        'Snow Falling on Cedars', "Everything's Eventual : 14 Dark Tales",
#        'Here on Earth', 'The Lost World',
#        "The Shelters of Stone (Earth's Children Series, No 5)",
#        'White Oleander : A Novel', "CAT'S EYE", "The Handmaid's Tale",
#        'The Girl Who Loved Tom Gordon : A Novel', 'The Murder Book',
#        'Body of Lies', 'Ishmael: An Adventure of the Mind and Spirit',
#        'Lightning', 'Hearts In Atlantis', 'Eyes of the Dragon',
#        "The Dive From Clausen's Pier : A Novel (Vintage Contemporaries (Paperback))",
#        'The Simple Truth', 'A Light in the Window (The Mitford Years)',
#        '1984', 'The Mists of Avalon',
#        'Hot Six : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#        'Jemima J: A Novel About Ugly Ducklings and Swans',
#        "Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#        'Sea Glass: A Novel', 'Daughter of Fortune: A Novel',
#        'Seven Habits Of Highly Effective People', 'Fahrenheit 451',
#        "Ender's Game (Ender Wiggins Saga (Paperback))",
#        'The Andromeda Strain', 'Loves Music, Loves to Dance',
#        'The Killer Angels', 'Dolores Claiborne',
#        'The Eye of the World (The Wheel of Time, Book 1)',
#        'Clear and Present Danger (Jack Ryan Novels)',
#        "Tuesdays with Morrie: An Old Man, a Young Man, and Life's Greatest Lesson",
#        'Pigs in Heaven', 'Tell No One',
#        'Eats, Shoots &amp; Leaves: The Zero Tolerance Approach to Punctuation',
#        'Waiting (Vintage International)',
#        'The Sum of All Fears (Jack Ryan Novels)', 'Icebound',
#        'Mystic River', 'The Jester', 'Sick Puppy', 'Prey', 'Fear Nothing',
#        'J Is for Judgment',
#        'A Is for Alibi (Kinsey Millhone Mysteries (Paperback))', 'Sphere',
#        'Slow Waltz in Cedar Bend', 'The Pelican Brief',
#        'Bridget Jones: The Edge of Reason',
#        "Don't Stand Too Close to a Naked Man",
#        'Interview with the Vampire',
#        'The Queen of the Damned (Vampire Chronicles (Paperback))',
#        '\\O\\" Is for Outlaw"',
#        "The Book of Ruth (Oprah's Book Club (Paperback))",
#        'How to Be Good', 'The Color Purple', 'The Notebook',
#        'A Beautiful Mind: The Life of Mathematical Genius and Nobel Laureate John Nash',
#        'You Belong To Me', 'Peace Like a River', 'Cry Wolf',
#        'Montana Sky', 'Diary of a Mad Bride (Summer Display Opportunity)',
#        'Carolina Moon', 'Standing in the Rainbow',
#        "East of Eden (Oprah's Book Club)", 'Three Fates',
#        'Pay It Forward', 'Bastard Out of Carolina',
#        'Face the Fire (Three Sisters Island Trilogy)',
#        'Stupid White Men ...and Other Sorry Excuses for the State of the Nation!',
#        "Harry Potter and the Sorcerer's Stone (Book 1)",
#        "Dude, Where's My Country?", 'Bee Season: A Novel',
#        "ANGELA'S ASHES", 'Violets Are Blue',
#        'The Dogs of Babel (Today Show Book Club #12)',
#        'The Tale of the Body Thief (Vampire Chronicles (Paperback))',
#        'Cruel &amp; Unusual (Kay Scarpetta Mysteries (Paperback))',
#        'Misery', 'The Eyre Affair: A Novel', 'The Body Farm', 'Intensity',
#        'Dark Rivers of the Heart', 'Mr. Murder', 'The Hours: A Novel',
#        "The Bonesetter's Daughter", 'Midwives: A Novel',
#        "Song of Solomon (Oprah's Book Club (Paperback))",
#        'Atlas Shrugged', 'I Know This Much Is True',
#        'To the Nines: A Stephanie Plum Novel',
#        "Don't Sweat the Small Stuff and It's All Small Stuff : Simple Ways to Keep the Little Things from Taking Over Your Life (Don't Sweat the Small Stuff Series)",
#        'Monster : A Novel (Alex Delaware Novels (Paperback))',
#        'Call of the Wild', 'Girl, Interrupted', 'Wish You Well',
#        'Four To Score (A Stephanie Plum Novel)', 'Rising Tides',
#        'Watership Down', 'High Five (A Stephanie Plum Novel)',
#        'Five Quarters of the Orange',
#        'Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies',
#        "The Dive From Clausen's Pier (Alex Awards)",
#        'A Child Called \\It\\": One Child\'s Courage to Survive"',
#        'Final Target', 'A Map of the World', 'Siddhartha',
#        'Tribulation Force: The Continuing Drama of Those Left Behind (Left Behind No. 2)',
#        'The Runaway Jury', 'Without Remorse',
#        'The Bear and the Dragon (Jack Ryan Novels)',
#        'The Woman Next Door',
#        'The Divine Secrets of the Ya-Ya Sisterhood: A Novel',
#        'The Color of Magic',
#        'The Hobbit : The Enchanting Prelude to The Lord of the Rings',
#        'Chicken Soup for the Teenage Soul (Chicken Soup for the Soul)',
#        'Contact', 'The Temple of My Familiar',
#        'Harry Potter and the Chamber of Secrets (Book 2)',
#        'Love in the Time of Cholera (Penguin Great Books of the 20th Century)',
#        'Ashes to Ashes',
#        'The Professor and the Madman: A Tale of Murder, Insanity, and the Making of The Oxford English Dictionary',
#        "The Plains of Passage (Earth's Children (Paperback))",
#        'Cane River', 'The Surgeon', 'Presumed Innocent',
#        'Anne of Avonlea (Anne of Green Gables Novels (Paperback))',
#        'Pleading Guilty',
#        'Politically Correct Bedtime Stories: Modern Tales for Our Life and Times',
#        '4 Blondes', 'Night', 'STONES FROM THE RIVER', 'Falling Angels',
#        'The Valley of Horses', 'Desperation',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        "Charlotte's Web (Trophy Newbery)",
#        'The Lottery Winner : Alvirah And Willy Stories',
#        'Lucky : A Memoir', 'Let Me Call You Sweetheart',
#        'K Is for Killer (Kinsey Millhone Mysteries (Paperback))',
#        'Unspeakable', 'Irish Hearts',
#        'Catch Me If You Can: The True Story of a Real Fake',
#        'Circle of Friends', 'The Bourne Identity', 'Under the Tuscan Sun',
#        'Tis: A Memoir', 'The Cardinal of the Kremlin (Jack Ryan Novels)',
#        'Bag of Bones', 'The Prince of Tides', 'A Bend in the Road',
#        'Shopaholic Ties the Knot', 'One Door Away from Heaven',
#        'How the Garcia Girls Lost Their Accents (Plume Contemporary Fiction)',
#        'The Bridges of Madison County',
#        'The Return of the King (The Lord of the Rings, Part 3)',
#        'High Fidelity', 'A Confederacy of Dunces (Evergreen Book)',
#        'Mrs Dalloway', 'Prodigal Summer', 'Flesh and Blood',
#        "White Oleander : A Novel (Oprah's Book Club)",
#        'Confessions of an Ugly Stepsister : A Novel',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Dying for Chocolate (Culinary Mysteries (Paperback))', 'The Reef',
#        'House of Sand and Fog', 'Saving Faith', 'The Mulberry Tree',
#        'White Teeth: A Novel',
#        "Sophie's World: A Novel About the History of Philosophy",
#        'Silence of the Lambs', 'The Hot Zone', 'The Rapture of Canaan',
#        'Heaven and Earth (Three Sisters Island Trilogy)',
#        'Dance upon the Air (Three Sisters Island Trilogy)',
#        'What Looks Like Crazy On An Ordinary Day',
#        "Angela's Ashes (MMP) : A Memoir", 'The Corrections: A Novel',
#        'Shopgirl : A Novella',
#        'The Reptile Room (A Series of Unfortunate Events, Book 2)',
#        'Coraline', 'Long After Midnight',
#        'Stranger in a Strange Land (Remembering Tomorrow)', 'Disclosure',
#        "The Idiot Girls' Action Adventure Club", 'The Corrections',
#        'The Golden Compass (His Dark Materials, Book 1)',
#        "The Pilot's Wife : A Novel", 'About a Boy', 'A Patchwork Planet',
#        'Prey: A Novel', 'Blessings', 'Shell Seekers', 'A Case of Need',
#        'Blow Fly: A Scarpetta Novel', 'The Devil Wears Prada : A Novel',
#        'On the Street Where You Live', 'Prodigal Summer: A Novel',
#        'We Were the Mulvaneys', 'Brave New World',
#        'Balzac and the Little Chinese Seamstress : A Novel',
#        'Year of Wonders', 'All I Really Need to Know',
#        'Running with Scissors: A Memoir', 'Tara Road', "Hornet's Nest",
#        "The Handmaid's Tale : A Novel", 'Chocolat', 'The Green Mile',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        "Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death",
#        'P Is for Peril', 'Beach House',
#        'The Celestine Prophecy (Celestine Prophecy)',
#        'Harry Potter and the Order of the Phoenix (Book 5)', 'Insomnia',
#        'Hideaway', 'The Tommyknockers',
#        'Tears of the Giraffe (No.1 Ladies Detective Agency)',
#        'Rainbow Six', 'A Walk to Remember', 'Holes (Yearling Newbery)',
#        'The Summons', 'The Third Twin', 'The Winner', 'The Villa',
#        'The Virgin Suicides', "From Potter's Field", 'The Summerhouse',
#        'Cold Mountain', 'The Blind Assassin',
#        'D Is for Deadbeat (Kinsey Millhone Mysteries (Paperback))',
#        'Midnight in the Garden of Good and Evil',
#        'Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#        'Two for the Dough', 'Where the Red Fern Grows',
#        'The Eyes of Darkness',
#        'Portrait of a Killer: Jack the Ripper -- Case Closed', 'Envy',
#        'Big Trouble', "The Samurai's Garden : A Novel", 'Dead Sleep',
#        'The Dark Half', 'Fast Women',
#        "Full House (Janet Evanovich's Full Series)",
#        'F Is for Fugitive (Kinsey Millhone Mysteries (Paperback))',
#        'E Is for Evidence: A Kinsey Millhone Mystery (Kinsey Millhone Mysteries (Paperback))',
#        'Plum Island', 'Beloved', "The Sweet Potato Queens' Book of Love",
#        "Drowning Ruth (Oprah's Book Club)", 'The Last Precinct',
#        'September', 'Possession : A Romance', 'L Is for Lawless',
#        'Turtle Moon', 'The Cider House Rules', 'Animal Dreams',
#        'Sleepers', 'Coast Road: A Novel', 'The Angel of Darkness',
#        "Jewel (Oprah's Book Club)", 'I Is for Innocent',
#        'Morality for Beautiful Girls (No.1 Ladies Detective Agency)',
#        'N Is for Noose', 'A Wrinkle in Time', 'The English Patient',
#        'I Know Why the Caged Bird Sings', 'The Hunt for Red October',
#        'Still Waters',
#        'Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#        "The No. 1 Ladies' Detective Agency",
#        'Debt of Honor (Jack Ryan Novels)',
#        "The Deep End of the Ocean (Oprah's Book Club (Hardcover))",
#        'Q Is for Quarry', "Full Tilt (Janet Evanovich's Full Series)",
#        "Open House (Oprah's Book Club (Paperback))",
#        'The Forgotten (Peter Decker &amp; Rina Lazarus Novels (Paperback))',
#        'The Glass Lake', 'The Horse Whisperer', 'River, Cross My Heart',
#        'Girl in Hyacinth Blue',
#        'Angus, Thongs and Full-Frontal Snogging: Confessions of Georgia Nicolson',
#        'Sea Swept (Quinn Brothers (Paperback))',
#        'P Is for Peril (Kinsey Millhone Mysteries (Hardcover))',
#        'The Weight of Water : A Novel Tag: Author of Resistance and Strange Fits of Passion',
#        'Hearts in Atlantis', 'It Was on Fire When I Lay Down on It',
#        'Total Control', 'Dust to Dust', 'Truly, Madly Manhattan',
#        'Survival of the Fittest: An Alex Delaware Novel',
#        'Southern Cross',
#        'Of Mice and Men (Penguin Great Books of the 20th Century)',
#        'B Is for Burglar (Kinsey Millhone Mysteries (Paperback))',
#        'C Is for Corpse (Kinsey Millhone Mysteries (Paperback))',
#        "Gerald's Game", 'FORREST GUMP (Movie Tie in)', 'Rose Madder',
#        'When the Wind Blows', 'Eaters of the Dead',
#        'Neuromancer (Remembering Tomorrow)',
#        "Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))",
#        'Last Chance Saloon', 'A Man in Full',
#        'Seven Up (A Stephanie Plum Novel)', 'Last Man Standing',
#        'The Stone Diaries', 'Open House', "The Pilot's Wife",
#        'Dune (Remembering Tomorrow)', 'Black House',
#        'A Thin Dark Line (Mysteries &amp; Horror)', 'The Perfect Husband',
#        'The Face of Deception',
#        'G Is for Gumshoe (Kinsey Millhone Mysteries (Paperback))',
#        'The Other Boleyn Girl', 'The Bonfire of the Vanities',
#        'Lake Wobegon days', 'The Search',
#        'Portrait of a Killer: Jack the Ripper-- Case Closed (Berkley True Crime)',
#        'A Girl Named Zippy: Growing Up Small in Mooreland Indiana (Today Show Book Club #3)',
#        'The Virgin Blue',
#        'The Bachelor (Warner Books Contemporary Romance)',
#        'The House of Thunder',
#        'The Bone Collector (Lincoln Rhyme Novels (Paperback))',
#        'Dr. Death (Alex Delaware Novels (Paperback))',
#        "One Flew Over the Cuckoo's Nest", 'Four Past Midnight',
#        'Men Are from Mars, Women Are from Venus: A Practical Guide for Improving Communication and Getting What You Want in Your Relationships',
#        'Outlander', 'Hemlock Bay', 'The Great Gatsby', 'Red Storm Rising',
#        'Tell Me Lies (Tell Me Lies)',
#        "Ahab's Wife: Or, The Star-Gazer: A Novel", 'Couplehood',
#        'Code to Zero', 'Hide &amp; Seek', 'Whirlwind (Tyler, Book 1)',
#        "Schindler's List", 'Drowning Ruth', 'Summer Pleasures',
#        "A Virtuous Woman (Oprah's Book Club (Paperback))",
#        'The Burden of Proof', 'False Memory', "Foucault's Pendulum",
#        'See How They Run', "The Liar's Club: A Memoir", 'One True Thing',
#        'The Killing Game: Only One Can Win...and the Loser Dies',
#        'Nightmares &amp; Dreamscapes', 'Watchers', 'Seize the Night',
#        'Needful Things', 'From a Buick 8 : A Novel',
#        'Welcome to the World, Baby Girl!', 'A Fine Balance', 'Deja Dead',
#        'The Ugly Duckling', 'In Her Shoes : A Novel',
#        "I Know This Much Is True (Oprah's Book Club)",
#        'Gap Creek: The Story Of A Marriage', 'The Hundred Secret Senses',
#        'Welcome to Temptation', 'Pop Goes the Weasel',
#        'Tears of the Moon (Irish Trilogy)', 'The Genesis Code', 'Riptide',
#        'The Accidental Tourist',
#        'The Gunslinger (The Dark Tower, Book 1)',
#        "The Lost Boy: A Foster Child's Search for the Love of a Family",
#        'The Honk and Holler Opening Soon', "Fortune's Rocks: A Novel",
#        'Unnatural Exposure', 'Shadowfires', 'Thousand Acres',
#        'Remember Me', 'The Key to Midnight', 'Winter Moon',
#        'Scarlet Feather', 'Lucky Man: A Memoir', 'Midnight Bayou',
#        "Big Cherry Holler: A Big Stone Gap Novel (Ballantine Reader's Circle)",
#        'Like Water for Chocolate : A Novel in Monthly Installments with Recipes, Romances, and Home Remedies',
#        'Beach Music', 'The Saving Graces: A Novel', 'Invasion', 'Moo',
#        "Tom Clancy's Op-Center: Mirror Image (Tom Clancy's Op Center (Paperback))",
#        'Cradle and All', 'Space', 'Atonement: A Novel',
#        'Nicolae: The Rise of Antichrist (Left Behind No. 3)',
#        'The Remains of the Day (Vintage International)',
#        'Acceptable Risk', 'The Sigma Protocol',
#        "The Clan of the Cave Bear (Earth's Children (Paperback))",
#        'Scarlett : The Sequel to Margaret Mitchell\'s \\Gone With the Wind\\""',
#        'Evening Class', 'On the Road', "The General's Daughter",
#        'Artemis Fowl (Artemis Fowl, Book 1)', 'The Copper Beech',
#        'Key of Knowledge (Key Trilogy (Paperback))',
#        'Key of Valor (Roberts, Nora. Key Trilogy, 3.)',
#        'Key of Light (Key Trilogy (Paperback))', 'Wifey',
#        'A Wrinkle In Time', 'The Bluest Eye', 'The Boy Next Door',
#        'Sanctuary',
#        'Soul Harvest: The World Takes Sides (Left Behind No. 4)',
#        'All the Pretty Horses (The Border Trilogy, Vol 1)',
#        'The Return Journey', 'Seinlanguage',
#        'The World According to Garp',
#        'The Stone Monkey (Lincoln Rhyme Novels (Paperback))',
#        'Jewels of the Sun (Irish Trilogy)',
#        'American Psycho (Vintage Contemporaries)',
#        'Silent Night : A Christmas Suspense Story',
#        'H Is for Homicide (Kinsey Millhone Mysteries (Paperback))',
#        'Executive Orders (Jack Ryan Novels)',
#        'Cat &amp; Mouse (Alex Cross Novels)', 'Blood Work', 'Mortal Prey',
#        'Patriot Games (Jack Ryan Novels)',
#        'Inner Harbor (Quinn Brothers (Paperback))',
#        'Lasher: Lives of the Mayfair Witches (Lives of the Mayfair Witches)',
#        'Crazy for You', 'That Camden Summer', 'Absolute Power',
#        'The Deep End of the Ocean', 'Jackdaws', 'Easy Prey',
#        'M Is for Malice', 'The Talisman', 'Angels',
#        'Eleventh Hour: An FBI Thriller (FBI Thriller (Jove Paperback))'],
#       dtype=object)

# %%
final_df_pivot.head()
# Out:
# user                                                254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
#
# user                                                2977    3363    4017    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
#
# user                                                4385    6242    6251    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
#
# user                                                6323    ...  274004  \
# title                                                       ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0  ...     0.0
#
# user                                                274061  274301  274308  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
#
# user                                                274808  275970  277427  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
#
# user                                                277478  277639  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
#
# [5 rows x 888 columns]

# %%
## function to return top n recommended books
def recommended_books(book = "", n = 5):
  titles = list(final_df_pivot.index.values)
  data = final_df_pivot.values

  def title_to_index(title):
    ind = titles.index(title)
    return data[ind,:]

  def index_to_title(ind):
    return titles[ind]
  model = NearestNeighbors(metric="cosine",algorithm="brute", p=2)
  model.fit(data)
  idx = title_to_index(book)
  distances, indices = model.kneighbors(
    np.reshape(idx,[1,-1]),
    n_neighbors=n+1
  )

  raw_recommends = sorted(
    list(
      zip(
        indices.squeeze().tolist(),
        distances.squeeze().tolist()
      )
    ),
    key=lambda x: x[1]
  )[1:]

  recommended_books = []
  print('Recommendations for {}:'.format(book))
  for i, (idx, dist) in enumerate(raw_recommends):
      dist = dist
      recommended_books.append([index_to_title(idx), dist])
      print('{0}: {1}, with distance of {2:,.2f}'.format(i+1, index_to_title(idx), dist))
  print('-----------------')
  return [book, recommended_books]

# %%
recommended_books_list = recommended_books("Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))", 10)
# Out:
# Recommendations for Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback)):
# 1: Harry Potter and the Chamber of Secrets (Book 2), with distance of 0.54
# 2: Harry Potter and the Prisoner of Azkaban (Book 3), with distance of 0.61
# 3: Harry Potter and the Goblet of Fire (Book 4), with distance of 0.65
# 4: Harry Potter and the Order of the Phoenix (Book 5), with distance of 0.73
# 5: A Time to Kill, with distance of 0.80
# 6: Three To Get Deadly : A Stephanie Plum Novel (A Stephanie Plum Novel), with distance of 0.80
# 7: Montana Sky, with distance of 0.81
# 8: Like Water for Chocolate: A Novel in Monthly Installments With Recipes, Romances and Home Remedies, with distance of 0.81
# 9: The Joy Luck Club, with distance of 0.81
# 10: Anne of Green Gables (Anne of Green Gables Novels (Paperback)), with distance of 0.81
# -----------------
